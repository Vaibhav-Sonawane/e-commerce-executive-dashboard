# %% [markdown]
# # Data Profiling

# %%
import pandas as pd

# %%
df=pd.read_csv("../data/processed/online_retail_II_processed.csv")

# %%
df.shape
# Out:
# (1067371, 8)

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='str')

# %%
df.columns.tolist()
# Out:
# ['Invoice',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'Price',
#  'Customer ID',
#  'Country']

# %%
df.dtypes
# Out:
# Invoice            str
# StockCode          str
# Description        str
# Quantity         int64
# InvoiceDate        str
# Price          float64
# Customer ID    float64
# Country            str
# dtype: object

# %%
df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(34335)

# %%
df.nunique()
# Out:
# Invoice        53628
# StockCode       5305
# Description     5698
# Quantity        1057
# InvoiceDate    47635
# Price           2807
# Customer ID     5942
# Country           43
# dtype: int64

# %%
df["InvoiceDate"].min()
# Out:
# '2009-12-01 07:45:00'

# %%
df["InvoiceDate"].max()
# Out:
# '2011-12-09 12:50:00'

# %%
(df["Quantity"]<0).sum()
# Out:
# np.int64(22950)

# %%
((df["Quantity"]<0) & (df["Invoice"].str.startswith("C"))).sum()
# Out:
# np.int64(19493)

# %%
((df["Quantity"]>0) & (df["Invoice"].str.startswith("C"))).sum()
# Out:
# np.int64(1)

# %%
((df["Quantity"]>0) & ~(df["Invoice"].str.startswith("C"))).sum()
# Out:
# np.int64(1044420)

# %%
((df["Quantity"]<0) & ~(df["Invoice"].str.startswith("C"))).sum()
# Out:
# np.int64(3457)

# %%
(df["Price"]==0).sum()
# Out:
# np.int64(6202)

# %%
df.loc[df["Price"] == 0, "StockCode"].unique()
# Out:
# <ArrowStringArray>
# [ '21733',  '71477', '85123A',  '21646',  '20683',  '21350',  '35956',
#  '35605A',  '84292',  '18010',
#  ...
#   '22217',  '23404',  '85104',  '21693',  '21688', '72801C',  '23395',
#   '22578',  '22576',  '23090']
# Length: 2971, dtype: str

# %%
df["Invoice"].str.startswith("C").sum()
# Out:
# np.int64(19494)

# %%
df.loc[
    ~df["StockCode"].str.contains(r"^\D+$", na=False),
    "StockCode"
].unique()
# Out:
# <ArrowStringArray>
# [ '85048', '79323P', '79323W',  '22041',  '21232',  '22064',  '21871',
#   '21523',  '22350',  '22349',
#  ...
#   '23578',  '23580',  '23575',  '23560',  '23576',  '23562',  '23561',
#   '23609',  '23617',  '23843']
# Length: 5288, dtype: str

# %%
df[df["StockCode"].str.startswith("TEST")].nunique()
# Out:
# Invoice        17
# StockCode       2
# Description     1
# Quantity        5
# InvoiceDate    17
# Price           3
# Customer ID     5
# Country         1
# dtype: int64

# %%
df.loc[
    (df["Quantity"] < 0) & ~(df["Invoice"].str.startswith("C")),
    "StockCode"
].value_counts().head(30)
# Out:
# StockCode
# 22423     12
# 46000M     6
# 82494L     6
# 22719      6
# 46000S     5
# 84016      5
# 85017A     5
# 47566B     5
# 20852      5
# 85175      5
# 21830      5
# 71477      4
# 21768      4
# 84559D     4
# 84990      4
# 22028      4
# 35972      4
# 21040      4
# 79000      4
# 20713      4
# 21843      4
# 37476      4
# 84406B     4
# 85126      4
# 21763      4
# 37464      4
# 21161      4
# 22162      4
# 22034      4
# 20966      4
# Name: count, dtype: int64

# %%
df[(df["StockCode"].str.startswith("46000S")) & ~(df["Invoice"].str.startswith("C")) & (df["Quantity"]<0)]
# Out:
#        Invoice StockCode   Description  Quantity          InvoiceDate  Price  \
# 108086  499767    46000S           NaN       -20  2010-03-02 13:19:00    0.0
# 525234  538161    46000S  Dotcom sales      -100  2010-12-09 17:25:00    0.0
# 547758  538161    46000S  Dotcom sales      -100  2010-12-09 17:25:00    0.0
# 590538  541687    46000S        Dotcom      -300  2011-01-20 15:42:00    0.0
# 957260  573752    46000S  dotcom sales       -90  2011-11-01 09:34:00    0.0
#
#         Customer ID         Country
# 108086          NaN  United Kingdom
# 525234          NaN  United Kingdom
# 547758          NaN  United Kingdom
# 590538          NaN  United Kingdom
# 957260          NaN  United Kingdom

# %%
df[(df["Invoice"].str.startswith("C")) & (df["Quantity"]>0)]
# Out:
#        Invoice StockCode Description  Quantity          InvoiceDate   Price  \
# 76799  C496350         M      Manual         1  2010-02-01 08:24:00  373.57
#
#        Customer ID         Country
# 76799          NaN  United Kingdom

# %%
df[df["StockCode"].str.startswith("DCGSLGIRL")]
# Out:
#        Invoice  StockCode Description  Quantity          InvoiceDate  Price  \
# 101693  499042  DCGSLGIRL         NaN       -57  2010-02-24 13:31:00    0.0
#
#         Customer ID         Country
# 101693          NaN  United Kingdom

# %%
df[df["StockCode"].str.startswith("ADJUST")].nunique()
# Out:
# Invoice        70
# StockCode       2
# Description     4
# Quantity        2
# InvoiceDate    47
# Price          62
# Customer ID    53
# Country        11
# dtype: int64

# %%
df[df.duplicated(keep=False)]
# Out:
#         Invoice StockCode                        Description  Quantity  \
# 362      489517     21913     VINTAGE SEASIDE JIGSAW PUZZLES         1
# 363      489517     21912           VINTAGE SNAKES & LADDERS         1
# 365      489517     21821   GLITTER STAR GARLAND WITH BELLS          1
# 367      489517     22319  HAIRCLIPS FORTIES FABRIC ASSORTED        12
# 368      489517     22130   PARTY CONE CHRISTMAS DECORATION          6
# ...         ...       ...                                ...       ...
# 1067136  581538     22068        BLACK PIRATE TREASURE CHEST         1
# 1067150  581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 1067153  581538     22992             REVOLVER WOODEN RULER          1
# 1067160  581538     22694                       WICKER STAR          1
# 1067162  581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(34335)

# %%
df[df.duplicated(keep=False)].groupby(list(df.columns)).size()
# Out:
# Invoice  StockCode  Description                          Quantity  InvoiceDate          Price  Customer ID  Country
# 489517   21491      SET OF THREE VINTAGE GIFT WRAPS       1        2009-12-01 11:34:00  1.95   16329.0      United Kingdom    2
#          21821      GLITTER STAR GARLAND WITH BELLS       1        2009-12-01 11:34:00  3.75   16329.0      United Kingdom    2
#          21912      VINTAGE SNAKES & LADDERS              1        2009-12-01 11:34:00  3.75   16329.0      United Kingdom    3
#          21913      VINTAGE SEASIDE JIGSAW PUZZLES        1        2009-12-01 11:34:00  3.75   16329.0      United Kingdom    2
#          22130      PARTY CONE CHRISTMAS DECORATION       6        2009-12-01 11:34:00  0.85   16329.0      United Kingdom    2
#                                                                                                                              ..
# ...

# %%
df[df.duplicated(keep=False)].value_counts()
# Out:
# Invoice  StockCode  Description                          Quantity  InvoiceDate          Price  Customer ID  Country
# 555524   22698      PINK REGENCY TEACUP AND SAUCER       1         2011-06-05 11:37:00  2.95   16923.0      United Kingdom    20
#          22697      GREEN REGENCY TEACUP AND SAUCER      1         2011-06-05 11:37:00  2.95   16923.0      United Kingdom    12
# 537224   70007      HI TEC ALPINE HAND WARMER            1         2010-12-05 16:24:00  1.65   13174.0      United Kingdom    10
# 572861   22775      PURPLE DRAWERKNOB ACRYLIC EDWARDIAN  12        2011-10-26 12:46:00  1.25   14102.0      United Kingdom     8
# 496431   84826      ASSTD DESIGN 3D PAPER STICKERS       1         2010-02-01 12:30:00  0.85   16415.0      United Kingdom     6
#                                                                                                                               ..
# ...

# %%
df.groupby(list(df.columns)).size().loc[lambda x: x > 1].sort_values(ascending=False).head(20)
# Out:
# Invoice  StockCode  Description                          Quantity  InvoiceDate          Price  Customer ID  Country
# 555524   22698      PINK REGENCY TEACUP AND SAUCER       1         2011-06-05 11:37:00  2.95   16923.0      United Kingdom    20
#          22697      GREEN REGENCY TEACUP AND SAUCER      1         2011-06-05 11:37:00  2.95   16923.0      United Kingdom    12
# 537224   70007      HI TEC ALPINE HAND WARMER            1         2010-12-05 16:24:00  1.65   13174.0      United Kingdom    10
# 572861   22775      PURPLE DRAWERKNOB ACRYLIC EDWARDIAN  12        2011-10-26 12:46:00  1.25   14102.0      United Kingdom     8
# 578289   23395      BELLE JARDINIERE CUSHION COVER       1         2011-11-23 14:07:00  3.75   17841.0      United Kingdom     6
# 536749   22174      PHOTO CUBE                           2         2010-12-02 13:49:00  1.65   17976.0      United Kingdom     6
# ...

# %%
df[df.duplicated(keep=False)]["Invoice"].value_counts().head(20)
# Out:
# Invoice
# 537434    1350
# 538071    1304
# 537638    1202
# 537237    1194
# 536876    1186
# 536592    1184
# 537823    1182
# 537240    1136
# 537666    1072
# 536544    1054
# 537224     338
# 537781     322
# 537640     298
# 536982     290
# 536865     280
# 537643     246
# 537642     244
# 536796     242
# 538153     242
# 537126     236
# Name: count, dtype: int64
